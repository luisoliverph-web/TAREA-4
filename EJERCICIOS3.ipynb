# %% [markdown]
# <a href="https://colab.research.google.com/github/luisoliverph-web/TAREA-4/blob/main/EJERCICIOS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EJERCICIOS DE SISTEMAS DE ECUACIONES

# %% [markdown]
# Ejercicio nº 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sistema de ecuaciones
a = np.array([[5,2],[-3,3]])
b = np.array([1,5])
sol = np.linalg.solve(a,b)
x_sol, y_sol = sol

# Rango de x para graficar las líneas
x = np.linspace(-2, 2, 400)

# Ecuaciones despejadas para y
y1 = (1 - 5*x)/2
y2 = (5 + 3*x)/3

plt.figure(figsize=(8,6))
plt.plot(x, y1, label='5x + 2y = 1')
plt.plot(x, y2, label='-3x + 3y = 5')
plt.plot(x_sol, y_sol, 'ro', label=f"Solución: x = {x_sol}, y = {y_sol}")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[2, 1], [4, 3]])
b = np.array([6, 14])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol

x = np.linspace(0, 4, 100)
y1 = (6 - 2*x)       # de 2x + y = 6  => y = 6 - 2x
y2 = (14 - 4*x)/3    # de 4x + 3y = 14 => y = (14 - 4x)/3

plt.plot(x, y1, label='2x + y = 6')
plt.plot(x, y2, label='4x + 3y = 14')
plt.plot(x_sol, y_sol, 'ro', label=f"Solución: x = {x_sol}, y = {y_sol}")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Ejercicio nº 2

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[5,-2], [1, 2]])
b = np.array([2, 2])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 = (2 - 5*x)/-2
y2 = (2 - x)/2
plt.plot(x, y1, label='5x - 2y = 2')
plt.plot(x, y2, label='x + 2y = 2')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 0.6666666666666667, y = 0.6666666666666667

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[5, -1], [-2, 4]])
b = np.array([3, 12])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 = 5*x - 3
y2 = (12 + 2*x)/4

plt.plot(x, y1, label='5x - y = 3')
plt.plot(x, y2, label='-2x + 4y = 12')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 1.3333333333333333, y = 3.6666666666666665

# %% [markdown]
# Ejercicio nº 3

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[3, 5], [2, -3]])
b = np.array([15, -9])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 = (15 - 3*x)/5
y2 = (9 + 2*x)/3

plt.plot(x, y1, label='3x + 5y = 15')
plt.plot(x, y2, label='2x - 3y = -9')

plt.plot(x_sol, y_sol, 'ro', label='Solución')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 0.0, y = 3.0

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[4, 6], [6, 5]])
b = np.array([2, 1])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 = (2 - 4*x)/6
y2 = (1 - 6*x)/5

plt.plot(x, y1, label='4x + 6y = 2')
plt.plot(x, y2, label='6x + 5y = 1')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = -0.25, y = 0.5

# %% [markdown]
# Ejercicio nº 4

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[-2, 3], [3, -1]])
b = np.array([14, -14])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol:.2f}")


x = np.linspace(-2, 2, 100)
y1 = (14 + 2*x)/3
y2 = (-14 - 3*x)/-1

plt.plot(x, y1, label='-2x + 3y = 14')
plt.plot(x, y2, label='3x - y = -14')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = -4.0, y = 2.00

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[2, 3], [-6, 12]])
b = np.array([2, 1])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (2 - 2*x)/3
y2 =  (1 + 6*x)/12

plt.plot(x, y1, label='2x + 3y = 2')
plt.plot(x, y2, label='-6x + 12y = 1')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 0.5, y = 0.33333333333333337

# %% [markdown]
# Ejercicio nº 5

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[5, 2], [2, -3]])
b = np.array([11, 12])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (11 - 5*x)/2
y2 =  (12 - 2*x)/-3

plt.plot(x, y1, label='5x + 2y = 11')
plt.plot(x, y2, label='2x - 3y = 12')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 3.0, y = -2.0

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[-2, 4], [3, -5]])
b = np.array([7, 4])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (7  + 2*x)/4
y2 =  (4 - 3*x)/-5

plt.plot(x, y1, label='-2x + 4y = 7')
plt.plot(x, y2, label='3x - 5y = 4')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 25.49999999999999, y = 14.499999999999993

# %% [markdown]
# Ejercicio nº 6

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[1, 2], [-3, 1]])
b = np.array([1, -10])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 = (1 - x)/2
y2 =  (-10 + 3*x)/1

plt.plot(x, y1, label='x + 2y = 1')
plt.plot(x, y2, label='-3x + y =-10')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 3.0, y = -0.9999999999999998

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[-1, 2], [2, -4]])
b = np.array([4, 3])

# Calculate the determinant to confirm it's singular
det_a = np.linalg.det(a)
print(f"Determinante de la matriz a: {det_a}")

# Check if the determinant is close to zero (due to floating point arithmetic)
if np.isclose(det_a, 0):
    print("La matriz es singular. El sistema no tiene una solución única (líneas paralelas o coincidentes).")
    # The system is:
    # -x + 2y = 4
    # 2x - 4y = 3
    # Notice that the second equation can be rewritten as -x + 2y = 3/2.
    # Since -x + 2y cannot be both 4 and 3/2, the lines are parallel and distinct.
    print("Como -x + 2y = 4 y 2x - 4y = 3 (lo que implica -x + 2y = 3/2), las líneas son paralelas y distintas, por lo tanto, no hay solución.")
else:
    sol = np.linalg.solve(a, b)
    x_sol, y_sol = sol
    print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-5, 5, 100) # Extend range to better visualize parallelism
y1 =  (4  + 1*x)/2
y2 =  (3 - 2*x)/-4

plt.figure(figsize=(8,6))
plt.plot(x, y1, label='-x + 2y = 4')
plt.plot(x, y2, label='2x - 4y = 3', linestyle='--') # Use different linestyle for clarity

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales (Líneas Paralelas)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Determinante de la matriz a: 0.0
# La matriz es singular. El sistema no tiene una solución única (líneas paralelas o coincidentes).
# Como -x + 2y = 4 y 2x - 4y = 3 (lo que implica -x + 2y = 3/2), las líneas son paralelas y distintas, por lo tanto, no hay solución.

# %% [markdown]
# Ejercicio nº 7

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[1, 4], [2, 1]])
b = np.array([1, -5])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (1  - 1*x)/4
y2 =  (-5 - 2*x)/1

plt.plot(x, y1, label='x + 4y = 1')
plt.plot(x, y2, label='2x + y = -5')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = -3.0, y = 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[3, 1], [-6, -2]])
b = np.array([4, 1])

# Calculate the determinant to confirm it's singular
det_a = np.linalg.det(a)
print(f"Determinante de la matriz a: {det_a}")

# Check if the determinant is close to zero (due to floating point arithmetic)
if np.isclose(det_a, 0):
    print("La matriz es singular. El sistema no tiene una solución única (líneas paralelas o coincidentes).")
    # The system is:
    # 3x + y = 4
    # -6x - 2y = 1
    # Notice that if we multiply the first equation by -2, we get -6x - 2y = -8.
    # Since -6x - 2y cannot be both 1 and -8, the lines are parallel and distinct.
    print("Como 3x + y = 4 (lo que implica -6x - 2y = -8) y -6x - 2y = 1, las líneas son paralelas y distintas, por lo tanto, no hay solución.")
else:
    sol = np.linalg.solve(a, b)
    x_sol, y_sol = sol
    print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (4  - 3*x)/1
y2 =  (1 + 6*x)/-2

plt.figure(figsize=(8,6))
plt.plot(x, y1, label='3x + y = 4')
plt.plot(x, y2, label='-6x - 2y = 1', linestyle='--') # Use different linestyle for clarity

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales (Líneas Paralelas)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Determinante de la matriz a: 0.0
# La matriz es singular. El sistema no tiene una solución única (líneas paralelas o coincidentes).
# Como 3x + y = 4 (lo que implica -6x - 2y = -8) y -6x - 2y = 1, las líneas son paralelas y distintas, por lo tanto, no hay solución.

# %% [markdown]
# Ejercicio nº 8

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[3, -2], [2, 1]])
b = np.array([-4, 2])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (-4  - 3*x)/-2
y2 =  (2 - 2*x)/1

plt.plot(x, y1, label='3x - 2y = -4')
plt.plot(x, y2, label='2x + y = 2')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 0.0, y = 2.0

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[1, -4], [3, -12]])
b = np.array([5, 15])

# Calculate the determinant to confirm it's singular
det_a = np.linalg.det(a)
print(f"Determinante de la matriz a: {det_a}")

# Check if the determinant is close to zero
if np.isclose(det_a, 0):
    print("La matriz es singular. El sistema no tiene una solución única.")
    # The system is:
    # x - 4y = 5
    # 3x - 12y = 15
    # Notice that the second equation is 3 times the first one.
    # This means the lines are coincident (the same line), and there are infinitely many solutions.
    print("Las ecuaciones representan la misma línea (líneas coincidentes), por lo tanto, tiene infinitas soluciones.")
else:
    sol = np.linalg.solve(a, b)
    x_sol, y_sol = sol
    print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (5  - 1*x)/-4
y2 =  (15 - 3*x)/-12 # This line is identical to y1

plt.figure(figsize=(8,6))
plt.plot(x, y1, label='x - 4y = 5')
plt.plot(x, y2, label='3x - 12y = 15 (Coincidente)', linestyle='--') # Use different linestyle for clarity

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales (Líneas Coincidentes)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Determinante de la matriz a: 0.0
# La matriz es singular. El sistema no tiene una solución única.
# Las ecuaciones representan la misma línea (líneas coincidentes), por lo tanto, tiene infinitas soluciones.

# %% [markdown]
# Ejercicio nº 9

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[2, 3], [3, 2]])
b = np.array([1, 4])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (1 - 2*x)/3
y2 =  (4 - 3*x)/2

plt.plot(x, y1, label='2x + 3y = 1')
plt.plot(x, y2, label='3x + 2y = 4')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = 2.0, y = -0.9999999999999999

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[4, -3], [-8, 6]])
b = np.array([5, 10])

# Calculate the determinant to confirm it's singular
det_a = np.linalg.det(a)
print(f"Determinante de la matriz a: {det_a}")

# Check if the determinant is close to zero (due to floating point arithmetic)
if np.isclose(det_a, 0):
    print("La matriz es singular. El sistema no tiene una solución única (líneas paralelas o coincidentes).")
    # The system is:
    # 4x - 3y = 5
    # -8x + 6y = 10
    # Notice that if we multiply the first equation by -2, we get -8x + 6y = -10.
    # Since -8x + 6y cannot be both 10 and -10, the lines are parallel and distinct.
    print("Como 4x - 3y = 5 (lo que implica -8x + 6y = -10) y -8x + 6y = 10, las líneas son paralelas y distintas, por lo tanto, no hay solución.")
else:
    sol = np.linalg.solve(a, b)
    x_sol, y_sol = sol
    print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (5  - 4*x)/-3
y2 =  (10 + 8*x)/6

plt.figure(figsize=(8,6))
plt.plot(x, y1, label='4x - 3y = 5')
plt.plot(x, y2, label='-8x + 6y = 10', linestyle='--') # Use different linestyle for clarity

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales (Líneas Paralelas)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Determinante de la matriz a: 0.0
# La matriz es singular. El sistema no tiene una solución única (líneas paralelas o coincidentes).
# Como 4x - 3y = 5 (lo que implica -8x + 6y = -10) y -8x + 6y = 10, las líneas son paralelas y distintas, por lo tanto, no hay solución.

# %% [markdown]
# Ejercicio nº 10

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[4, -1], [2, 2]])
b = np.array([-9, -2])
sol = np.linalg.solve(a, b)
x_sol, y_sol = sol
print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (-9  - 4*x)/-1
y2 =  (-2 - 2*x)/2

plt.plot(x, y1, label='4x - y = -9')
plt.plot(x, y2, label='2x + 2y = -2')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución: x = -2.0, y = 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([[5, -4], [-10, 8]])
b = np.array([3, -6])

# Calculate the determinant to confirm it's singular
det_a = np.linalg.det(a)
print(f"Determinante de la matriz a: {det_a}")

# Check if the determinant is close to zero (due to floating point arithmetic)
if np.isclose(det_a, 0):
    print("La matriz es singular. El sistema no tiene una solución única.")
    # The system is:
    # 5x - 4y = 3
    # -10x + 8y = -6
    # Notice that the second equation is -2 times the first one.
    # This means the lines are coincident (the same line), and there are infinitely many solutions.
    print("Las ecuaciones representan la misma línea (líneas coincidentes), por lo tanto, tiene infinitas soluciones.")
else:
    sol = np.linalg.solve(a, b)
    x_sol, y_sol = sol
    print(f"Solución: x = {x_sol}, y = {y_sol}")

x = np.linspace(-2, 2, 100)
y1 =  (3  - 5*x)/-4
y2 =  (-6 + 10*x)/8 # This line is identical to y1

plt.figure(figsize=(8,6))
plt.plot(x, y1, label='5x - 4y = 3')
plt.plot(x, y2, label='-10x + 8y = -6 (Coincidente)', linestyle='--') # Use different linestyle for clarity

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones lineales (Líneas Coincidentes)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Determinante de la matriz a: 0.0
# La matriz es singular. El sistema no tiene una solución única.
# Las ecuaciones representan la misma línea (líneas coincidentes), por lo tanto, tiene infinitas soluciones.

# %% [markdown]
# Ejercicio nº 11

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x, y = sp.symbols('x y')

# Definir ecuaciones
eq1 = sp.Eq(2*(x + 4)/3 - y/2, 9/2)
eq2 = sp.Eq(x + 2*y - (1/3)*(3*x - 2), -4/3)

# Resolver sistema
sol = sp.solve((eq1, eq2), (x, y))
print(f"Solución exacta: x = {sol[x]}, y = {sol[y]}")

# Despejar y en ambas ecuaciones para graficar
y_expr1_solved = sp.solve(eq1, y)[0]
y_expr2_solved = sp.solve(eq2, y)[0]

# Convertir expresiones simbólicas a funciones numéricas
y_func1 = sp.lambdify(x, y_expr1_solved, "numpy")

# Crear rango de values para x
x_vals = np.linspace(-10, 10, 400)

# Graficar
plt.figure(figsize=(8,6))

# Plot the first equation
y_vals1 = y_func1(x_vals)
plt.plot(x_vals, y_vals1, label=f'Ecuación 1: {eq1}')


# Check if y_expr2_solved depends on x before lambdifying and plotting
if y_expr2_solved.has(x):
    y_func2 = sp.lambdify(x, y_expr2_solved, "numpy")
    y_vals2 = y_func2(x_vals)
    plt.plot(x_vals, y_vals2, label=f'Ecuación 2: {eq2}')
else:
    # If y_expr2_solved does not depend on x, it's a horizontal line at the solved y value
    plt.axhline(y=float(sol[y]), color='orange', linestyle='--', label=f'Ecuación 2: {eq2}')


# Plot the solution point
plt.plot(float(sol[x]), float(sol[y]), 'ro', label='Solución')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de sistema con fracciones usando SymPy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución exacta: x = 2.00000000000000, y = -1.00000000000000

# %% [markdown]
# Ejercicio nº 12

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x, y = sp.symbols('x y')

# Definir ecuaciones
eq1 = sp.Eq((2*x-1)/2 + (y-3)/3, 11/6)
eq2 = sp.Eq(-(2*x)/5 + (y-1)/10, -6/5)

# Resolver sistema
sol = sp.solve((eq1, eq2), (x, y))
print(f"Solución exacta: x = {sol[x]}, y = {sol[y]}")

# Despejar y en ambas ecuaciones para graficar
y_expr1_solved = sp.solve(eq1, y)[0]
y_expr2_solved = sp.solve(eq2, y)[0]

# Convertir expresiones simbólicas a funciones numéricas
y_func1 = sp.lambdify(x, y_expr1_solved, "numpy")

# Crear rango de valores para x
x_vals = np.linspace(-10, 10, 400)

# Graficar
plt.figure(figsize=(8,6))

# Graficar primera ecuación
y_vals1 = y_func1(x_vals)
plt.plot(x_vals, y_vals1, label='Ecuación 1')

# Graficar segunda ecuación (considera si es línea horizontal o no)
if y_expr2_solved.has(x):
    y_func2 = sp.lambdify(x, y_expr2_solved, "numpy")
    y_vals2 = y_func2(x_vals)
    plt.plot(x_vals, y_vals2, label='Ecuación 2')
else:
    # Línea horizontal
    plt.axhline(y=float(sol[y]), color='orange', linestyle='--', label='Ecuación 2 (línea horizontal)')

# Graficar punto solución
plt.plot(float(sol[x]), float(sol[y]), 'ro', label='Solución')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones con fracciones - Gráfica')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución exacta: x = 3.00000000000000, y = 1.00000000000000

# %% [markdown]
# Ejercicio nº 13

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x, y = sp.symbols('x y')

# Definir ecuaciones corregidas
eq1 = sp.Eq((3*x - 2*y)/3 + 4*y, 13/3)
eq2 = sp.Eq(2*(-2*y + x)/3 - (3*x)/2, -13/6)

# Resolver sistema
sol = sp.solve((eq1, eq2), (x, y))
print(f"Solución exacta: x = {sol[x]}, y = {sol[y]}")

# Despejar y en ambas ecuaciones para graficar
y_expr1_solved = sp.solve(eq1, y)[0]
y_expr2_solved = sp.solve(eq2, y)[0]

# Convertir expresiones simbólicas a funciones numéricas
y_func1 = sp.lambdify(x, y_expr1_solved, "numpy")
y_func2 = sp.lambdify(x, y_expr2_solved, "numpy")

# Crear rango de valores para x
x_vals = np.linspace(-10, 10, 400)

# Graficar
plt.figure(figsize=(8,6))

# Graficar primera ecuación
y_vals1 = y_func1(x_vals)
plt.plot(x_vals, y_vals1, label='Ecuación 1')

# Graficar segunda ecuación
y_vals2 = y_func2(x_vals)
plt.plot(x_vals, y_vals2, label='Ecuación 2')

# Graficar punto solución
plt.plot(float(sol[x]), float(sol[y]), 'ro', label='Solución')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones con fracciones - Gráfica')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución exacta: x = 1.00000000000000, y = 1.00000000000000

# %% [markdown]
# Ejercicio nº 14

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x, y = sp.symbols('x y')

# Definir ecuaciones corregidas
eq1 = sp.Eq(2*(x + 1)/3 - y, -3)
eq2 = sp.Eq(3*(x+5 - y)+3*x, 12)

# Resolver sistema
sol = sp.solve((eq1, eq2), (x, y))
print(f"Solución exacta: x = {sol[x]}, y = {sol[y]}")

# Despejar y en ambas ecuaciones para graficar
y_expr1_solved = sp.solve(eq1, y)[0]
y_expr2_solved = sp.solve(eq2, y)[0]

# Convertir expresiones simbólicas a funciones numéricas
y_func1 = sp.lambdify(x, y_expr1_solved, "numpy")
y_func2 = sp.lambdify(x, y_expr2_solved, "numpy")

# Crear rango de valores para x
x_vals = np.linspace(-10, 10, 400)

# Graficar
plt.figure(figsize=(8,6))

# Graficar primera ecuación
y_vals1 = y_func1(x_vals)
plt.plot(x_vals, y_vals1, label='Ecuación 1')

# Graficar segunda ecuación
y_vals2 = y_func2(x_vals)
plt.plot(x_vals, y_vals2, label='Ecuación 2')

# Graficar punto solución
plt.plot(float(sol[x]), float(sol[y]), 'ro', label='Solución')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones con fracciones - Gráfica')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución exacta: x = 2, y = 5

# %% [markdown]
# Ejercicio nº 15

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x, y = sp.symbols('x y')

# Definir ecuaciones corregidas
eq1 = sp.Eq((7*x - 9*y)/2 - (2*x+4)/2, -15)
eq2 = sp.Eq(5*(x-1+y), 25)

# Resolver sistema
sol = sp.solve((eq1, eq2), (x, y))
print(f"Solución exacta: x = {sol[x]}, y = {sol[y]}")

# Despejar y en ambas ecuaciones para graficar
y_expr1_solved = sp.solve(eq1, y)[0]
y_expr2_solved = sp.solve(eq2, y)[0]

# Convertir expresiones simbólicas a funciones numéricas
y_func1 = sp.lambdify(x, y_expr1_solved, "numpy")
y_func2 = sp.lambdify(x, y_expr2_solved, "numpy")

# Crear rango de valores para x
x_vals = np.linspace(-10, 10, 400)

# Graficar
plt.figure(figsize=(8,6))

# Graficar primera ecuación
y_vals1 = y_func1(x_vals)
plt.plot(x_vals, y_vals1, label='Ecuación 1')

# Graficar segunda ecuación
y_vals2 = y_func2(x_vals)
plt.plot(x_vals, y_vals2, label='Ecuación 2')

# Graficar punto solución
plt.plot(float(sol[x]), float(sol[y]), 'ro', label='Solución')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Sistema de ecuaciones con fracciones - Gráfica')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Solución exacta: x = 2, y = 4

# %% [markdown]
# Ejercicio nº 16

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x, y = sp.symbols('x y')

# Definir la ecuación
eq = sp.Eq(5*x - 4*y, 1)

# a) Buscar dos pares de valores que solucionan la ecuación
x_values = [0, 1]
solutions = []
for val in x_values:
    sol = sp.solve(eq.subs(x, val), y)
    solutions.append((val, sol[0]))

print("Dos pares de soluciones:")
for i, (x_val, y_val) in enumerate(solutions, 1):
    print(f"Solución {i}: x = {x_val}, y = {y_val}")

# b) Graficar la recta 5x - 4y = 1
# Despejar y para graficar: 5x -4y = 1 => y = (5x - 1)/4
y_expr = (5*x - 1)/4

# Convertir expresión simbólica a función numérica
y_func = sp.lambdify(x, y_expr, "numpy")

# Crear rango de valores para x
x_vals = np.linspace(-10, 10, 400)
y_vals = y_func(x_vals)

# Graficar
plt.figure(figsize=(8,6))
plt.plot(x_vals, y_vals, label='5x - 4y = 1')

# Graficar los puntos solución encontrados
for (x_sol, y_sol) in solutions:
    plt.plot(x_sol, float(y_sol), 'ro')
    plt.text(x_sol, float(y_sol), f'({x_sol},{y_sol})')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de la recta 5x - 4y = 1')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Dos pares de soluciones:
# Solución 1: x = 0, y = -1/4
# Solución 2: x = 1, y = 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir valores de x
x = np.linspace(-2, 2, 100)

# Despejar y
y = (5*x - 1)/4

# Graficar la recta
plt.plot(x, y, label='5x - 4y = 1')

# Marcar los dos puntos encontrados
plt.scatter([0, 1], [-0.25, 1], color='red', label='Puntos encontrados')

# Etiquetas

plt.xlabel('x')
plt.ylabel('y')
plt.title('Recta 5x - 4y = 1')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Definir variables
x, y = sp.symbols('x y')

# Definir la ecuación
eq = sp.Eq(5*x - 4*y, 1)

# a) Buscar dos pares de valores que solucionan la ecuación
x_values = [0, 1]
solutions = []
for val in x_values:
    sol = sp.solve(eq.subs(x, val), y)
    solutions.append((val, sol[0]))

print("Dos pares de soluciones:")
for i, (x_val, y_val) in enumerate(solutions, 1):
    print(f"Solución {i}: x = {x_val}, y = {y_val}")

# b) Graficar la recta 5x - 4y = 1
# Despejar y para graficar: 5x -4y = 1 => y = (5x - 1)/4
y_expr = (5*x - 1)/4

# Convertir expresión simbólica a función numérica
y_func = sp.lambdify(x, y_expr, "numpy")

# Crear rango de valores para x
x_vals = np.linspace(-10, 10, 400)
y_vals = y_func(x_vals)

# Graficar
plt.figure(figsize=(8,6))
plt.plot(x_vals, y_vals, label='5x - 4y = 1')

# Graficar los puntos solución encontrados
for (x_sol, y_sol) in solutions:
    plt.plot(x_sol, float(y_sol), 'ro')
    plt.text(x_sol, float(y_sol), f'({x_sol},{y_sol})')

# c) Mostrar la explicación en la gráfica
texto_explicacion = (
    "c) La recta está formada por todos los puntos (x, y) que satisfacen la ecuación.\n"
    "Cada punto sobre la recta es una solución de la ecuación.\n"
    "Las soluciones encontradas son solo ejemplos de todos los infinitos puntos en la recta."
)
plt.text(-9, max(y_vals)-2, texto_explicacion, fontsize=9, bbox=dict(facecolor='white', alpha=0.5))

plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de la recta 5x - 4y = 1')
plt.legend()
plt.grid(True)
plt.show()

# También imprimir la explicación en consola
print("\nc) Explicación:")
print(texto_explicacion)
# Out:
# Dos pares de soluciones:
# Solución 1: x = 0, y = -1/4
# Solución 2: x = 1, y = 1
# c) Explicación:
# c) La recta está formada por todos los puntos (x, y) que satisfacen la ecuación.
# Cada punto sobre la recta es una solución de la ecuación.
# Las soluciones encontradas son solo ejemplos de todos los infinitos puntos en la recta.

# %% [markdown]
# Ejercicio nº 17

# %%
import sympy as sp

# Variables simbólicas
x, y = sp.symbols('x y')

# Ecuación de la recta
eq = sp.Eq(3*x - 2*y, 1)

# Elegir valores de x y resolver para y
x_vals = [0, 2]  # puedes cambiar estos valores si deseas
puntos = []
for x_val in x_vals:
    y_val = sp.solve(eq.subs(x, x_val), y)[0]
    puntos.append((x_val, y_val))

print("a) Dos puntos que pertenecen a la recta 3x - 2y = 1:")
for i, (x_val, y_val) in enumerate(puntos, 1):
    print(f"Punto {i}: x = {x_val}, y = {y_val}")
# Out:
# a) Dos puntos que pertenecen a la recta 3x - 2y = 1:
# Punto 1: x = 0, y = -1/2
# Punto 2: x = 2, y = 5/2

# %%
print("b) Verificando si los puntos cumplen la ecuación 3x - 2y = 1:")

for i, (x_val, y_val) in enumerate(puntos, 1):
    resultado = 3 * x_val - 2 * y_val
    print(f"Punto {i}: 3*{x_val} - 2*{y_val} = {resultado} {'✅' if resultado == 1 else '❌'}")
# Out:
# b) Verificando si los puntos cumplen la ecuación 3x - 2y = 1:
# Punto 1: 3*0 - 2*-1/2 = 1 ✅
# Punto 2: 3*2 - 2*5/2 = 1 ✅

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Volver a definir variables y ecuación por si no están en memoria
x, y = sp.symbols('x y')
eq = sp.Eq(3*x - 2*y, 1)

# Despejar y: 3x - 2y = 1 → y = (3x - 1)/2
y_expr = sp.solve(eq, y)[0]
y_func = sp.lambdify(x, y_expr, 'numpy')

# Rango para x
x_vals = np.linspace(-10, 10, 400)
y_vals = y_func(x_vals)

# Usar los mismos puntos obtenidos en el apartado a)
puntos = [(0, sp.solve(eq.subs(x, 0), y)[0]),
          (2, sp.solve(eq.subs(x, 2), y)[0])]

# Graficar
plt.figure(figsize=(8,6))
plt.plot(x_vals, y_vals, label='Recta: 3x - 2y = 1', color='blue')

# Graficar los puntos en rojo
for (x_val, y_val) in puntos:
    plt.plot(x_val, float(y_val), 'ro')
    plt.text(x_val + 0.2, float(y_val), f'({x_val},{y_val})', fontsize=9)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de la recta 3x - 2y = 1')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)  # eje x
plt.axvline(0, color='black', linewidth=0.5)  # eje y
plt.legend()
plt.show()

# %% [markdown]
# Ejercicio nº 18

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Despejar y: 5x + 2y = 3 → y = (3 - 5x)/2
x = sp.symbols('x')
y_expr = (3 - 5*x)/2
y_func = sp.lambdify(x, y_expr, 'numpy')

# Rango de valores de x
x_vals = np.linspace(-10, 10, 400)
y_vals = y_func(x_vals)

# Graficar la recta
plt.figure(figsize=(8,6))
plt.plot(x_vals, y_vals, label='5x + 2y = 3', color='blue')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('a) Gráfica de la recta 5x + 2y = 3')
plt.grid(True)
plt.legend()
plt.show()

# %%
import sympy as sp

# Definir variables y ecuación
x, y = sp.symbols('x y')
eq = sp.Eq(5*x + 2*y, 3)

# La ecuación tiene infinitas soluciones (es una recta)
print("b) La ecuación tiene infinitas soluciones, porque representa una recta.")

# Obtener 2 soluciones eligiendo valores de x
soluciones = []
for x_val in [0, 1]:
    y_val = sp.solve(eq.subs(x, x_val), y)[0]
    soluciones.append((x_val, y_val))

# Mostrar soluciones
for i, (x_val, y_val) in enumerate(soluciones, 1):
    print(f"Solución {i}: x = {x_val}, y = {y_val}")
# Out:
# b) La ecuación tiene infinitas soluciones, porque representa una recta.
# Solución 1: x = 0, y = 3/2
# Solución 2: x = 1, y = -1

# %%
# Graficar la recta con puntos destacados
plt.figure(figsize=(8,6))
plt.plot(x_vals, y_vals, label='5x + 2y = 3', color='blue')

# Marcar soluciones
for (x_val, y_val) in soluciones:
    plt.plot(x_val, float(y_val), 'ro')
    plt.text(x_val + 0.3, float(y_val), f'({x_val},{y_val})', fontsize=9)

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('b) Soluciones de la ecuación sobre la recta')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Ejercicio nº 19

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

# Definir variables simbólicas
x, y = sp.symbols('x y')

# Definir la ecuación x + 2y = 4
eq = sp.Eq(x + 2*y, 4)

# Despejar y
y_expr = sp.solve(eq, y)[0]  # y = (4 - x)/2

# Convertir a función numérica
y_func = sp.lambdify(x, y_expr, 'numpy')

# Rango de valores para graficar
x_vals = np.linspace(-2, 6, 400)
y_vals = y_func(x_vals)

# Puntos que pertenecen a la recta
points = [(0, 2), (2, 1), (4, 0)]

# Graficar
plt.figure(figsize=(8,6))
plt.plot(x_vals, y_vals, label='x + 2y = 4', color='blue')
plt.scatter(*zip(*points), color='red', label='Puntos solución')

# Anotar los puntos
for (x_val, y_val) in points:
    plt.annotate(f'({x_val},{y_val})', (x_val, y_val), textcoords="offset points", xytext=(5,5), ha='left')

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Recta x + 2y = 4 usando SymPy y Matplotlib')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Ejercicio nº 20

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir la ecuación y = 6x + 10
x = np.array([-2, 0, 1, 2])
y = 6 * x + 10

# Graficar la recta
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='-3x + 0.5y = 5', color='blue')
plt.grid(True)

# Puntos de la recta y soluciones
points_x = [0, 1.5, 0, 1.5]  # Incluye (0, 10) y (1.5, 19)
points_y = [10, 19, 10, 19]
plt.scatter(points_x, points_y, color='red', label='Soluciones: (0,10), (1.5,19)')
for i, txt in enumerate(['(0,10)', '(1.5,19)']):
    plt.annotate(txt, (points_x[i], points_y[i]), xytext=(5, 5), textcoords='offset points')

# Etiquetas y leyenda
plt.xlabel('x')
plt.ylabel('y')
plt.title('Recta -3x + 0.5y = 5')
plt.legend()

# Mostrar gráfico
plt.show()
